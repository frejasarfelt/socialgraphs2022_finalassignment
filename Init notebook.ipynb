# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting fa2==0.3.5
#   Downloading fa2-0.3.5.tar.gz (435 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 435.4/435.4 KB 21.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: certifi in /shared-libs/python3.8/py/lib/python3.8/site-packages (from -r ./requirements.txt (line 3)) (2022.9.24)
# Collecting xmltodict==0.13.0
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Collecting python-louvain
#   Downloading python-louvain-0.16.tar.gz (204 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 KB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting networkx==2.8.8
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 33.9 MB/s eta 0:00:00
# Collecting wordcloud==1.8.2.2
#   Downloading wordcloud-1.8.2.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (458 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.0/459.0 KB 55.0 MB/s eta 0:00:00
# Collecting pyvis==0.3.1
#   Downloading pyvis-0.3.1.tar.gz (748 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 748.9/748.9 KB 15.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pandas==1.3.0
#   Downloading pandas-1.3.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (10.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 71.3 MB/s eta 0:00:00
# Collecting install
#   Downloading install-1.3.5-py3-none-any.whl (3.2 kB)
# Collecting requests_html==0.10.0
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: numpy in /shared-libs/python3.8/py/lib/python3.8/site-packages (from fa2==0.3.5->-r ./requirements.txt (line 2)) (1.23.4)
# Requirement already satisfied: scipy in /shared-libs/python3.8/py/lib/python3.8/site-packages (from fa2==0.3.5->-r ./requirements.txt (line 2)) (1.9.3)
# Requirement already satisfied: tqdm in /shared-libs/python3.8/py/lib/python3.8/site-packages (from fa2==0.3.5->-r ./requirements.txt (line 2)) (4.64.1)
# Requirement already satisfied: pillow in /shared-libs/python3.8/py/lib/python3.8/site-packages (from wordcloud==1.8.2.2->-r ./requirements.txt (line 10)) (9.2.0)
# Requirement already satisfied: matplotlib in /shared-libs/python3.8/py/lib/python3.8/site-packages (from wordcloud==1.8.2.2->-r ./requirements.txt (line 10)) (3.6.0)
# Requirement already satisfied: jinja2>=2.9.6 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from pyvis==0.3.1->-r ./requirements.txt (line 11)) (2.11.3)
# Requirement already satisfied: ipython>=5.3.0 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from pyvis==0.3.1->-r ./requirements.txt (line 11)) (8.5.0)
# Collecting jsonpickle>=1.4.1
#   Downloading jsonpickle-3.0.0-py2.py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 KB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from pandas==1.3.0->-r ./requirements.txt (line 12)) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from pandas==1.3.0->-r ./requirements.txt (line 12)) (2.8.2)
# Collecting pyppeteer>=0.0.14
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 KB 17.8 MB/s eta 0:00:00
# Requirement already satisfied: requests in /shared-libs/python3.8/py/lib/python3.8/site-packages (from requests_html==0.10.0->-r ./requirements.txt (line 16)) (2.28.1)
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyquery
#   Downloading pyquery-1.4.3-py3-none-any.whl (22 kB)
# Collecting parse
#   Downloading parse-1.19.0.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: w3lib in /shared-libs/python3.8/py/lib/python3.8/site-packages (from requests_html==0.10.0->-r ./requirements.txt (line 16)) (2.0.1)
# Collecting fake-useragent
#   Downloading fake_useragent-1.1.1-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 KB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: pickleshare in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis==0.3.1->-r ./requirements.txt (line 11)) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis==0.3.1->-r ./requirements.txt (line 11)) (2.13.0)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis==0.3.1->-r ./requirements.txt (line 11)) (0.17.2)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis==0.3.1->-r ./requirements.txt (line 11)) (4.8.0)
# Requirement already satisfied: matplotlib-inline in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis==0.3.1->-r ./requirements.txt (line 11)) (0.1.6)
# Requirement already satisfied: decorator in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis==0.3.1->-r ./requirements.txt (line 11)) (5.1.1)
# Requirement already satisfied: stack-data in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis==0.3.1->-r ./requirements.txt (line 11)) (0.5.1)
# Requirement already satisfied: backcall in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis==0.3.1->-r ./requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis==0.3.1->-r ./requirements.txt (line 11)) (3.0.31)
# Requirement already satisfied: traitlets>=5 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis==0.3.1->-r ./requirements.txt (line 11)) (5.5.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from jinja2>=2.9.6->pyvis==0.3.1->-r ./requirements.txt (line 11)) (2.0.1)
# Collecting pyee<9.0.0,>=8.1.0
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: importlib-metadata>=1.4 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests_html==0.10.0->-r ./requirements.txt (line 16)) (5.0.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from pyppeteer>=0.0.14->requests_html==0.10.0->-r ./requirements.txt (line 16)) (1.26.12)
# Collecting websockets<11.0,>=10.0
#   Downloading websockets-10.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 KB 26.6 MB/s eta 0:00:00
# Collecting appdirs<2.0.0,>=1.4.3
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: six>=1.5 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas==1.3.0->-r ./requirements.txt (line 12)) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from bs4->requests_html==0.10.0->-r ./requirements.txt (line 16)) (4.11.1)
# Requirement already satisfied: importlib-resources>=5.0 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from fake-useragent->requests_html==0.10.0->-r ./requirements.txt (line 16)) (5.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from matplotlib->wordcloud==1.8.2.2->-r ./requirements.txt (line 10)) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from matplotlib->wordcloud==1.8.2.2->-r ./requirements.txt (line 10)) (4.37.4)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from matplotlib->wordcloud==1.8.2.2->-r ./requirements.txt (line 10)) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from matplotlib->wordcloud==1.8.2.2->-r ./requirements.txt (line 10)) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from matplotlib->wordcloud==1.8.2.2->-r ./requirements.txt (line 10)) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from matplotlib->wordcloud==1.8.2.2->-r ./requirements.txt (line 10)) (0.11.0)
# Requirement already satisfied: lxml>=2.1 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from pyquery->requests_html==0.10.0->-r ./requirements.txt (line 16)) (4.9.1)
# Requirement already satisfied: cssselect>0.7.9 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from pyquery->requests_html==0.10.0->-r ./requirements.txt (line 16)) (1.1.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from requests->requests_html==0.10.0->-r ./requirements.txt (line 16)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from requests->requests_html==0.10.0->-r ./requirements.txt (line 16)) (3.4)
# Requirement already satisfied: zipp>=0.5 in /shared-libs/python3.8/py/lib/python3.8/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html==0.10.0->-r ./requirements.txt (line 16)) (3.9.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis==0.3.1->-r ./requirements.txt (line 11)) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis==0.3.1->-r ./requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=5.3.0->pyvis==0.3.1->-r ./requirements.txt (line 11)) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from beautifulsoup4->bs4->requests_html==0.10.0->-r ./requirements.txt (line 16)) (2.3.2.post1)
# Requirement already satisfied: executing in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from stack-data->ipython>=5.3.0->pyvis==0.3.1->-r ./requirements.txt (line 11)) (1.1.1)
# Requirement already satisfied: pure-eval in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from stack-data->ipython>=5.3.0->pyvis==0.3.1->-r ./requirements.txt (line 11)) (0.2.2)
# Requirement already satisfied: asttokens in /shared-libs/python3.8/py-core/lib/python3.8/site-packages (from stack-data->ipython>=5.3.0->pyvis==0.3.1->-r ./requirements.txt (line 11)) (2.0.8)
# Building wheels for collected packages: fa2, pyvis, python-louvain, bs4, parse
#   Building wheel for fa2 (setup.py): started
#   Building wheel for fa2 (setup.py): finished with status 'done'
#   Created wheel for fa2: filename=fa2-0.3.5-cp38-cp38-linux_x86_64.whl size=151330 sha256=20e675ed42a3630a4f8e50c05179b46fb2577c4a3a86df3019c536b4ad4fc20e
#   Stored in directory: /root/.cache/pip/wheels/19/f1/b6/a5c2c8bf19586118e21eb60d9c6dc3669d5dc341342f7a93e3
#   Building wheel for pyvis (setup.py): started
#   Building wheel for pyvis (setup.py): finished with status 'done'
#   Created wheel for pyvis: filename=pyvis-0.3.1-py3-none-any.whl size=755830 sha256=7dedcb491e72b5b671cd7b2541b7df273c0da252bc59455bd8422217d65fcd3e
#   Stored in directory: /root/.cache/pip/wheels/a4/0c/61/8469ca276f96ab772c3acc7f47d71e9737cbdf6f446f017f48
#   Building wheel for python-louvain (setup.py): started
#   Building wheel for python-louvain (setup.py): finished with status 'done'
#   Created wheel for python-louvain: filename=python_louvain-0.16-py3-none-any.whl size=9395 sha256=b8bc6cca3c48874a1d1a7e9ea7e497096ed0b597b7b20db7f330fd182c17bd45
#   Stored in directory: /root/.cache/pip/wheels/af/40/91/ef3635f7d3ddbd889b5af9f1ac22b8d30c48d6f744cd74a6d1
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1273 sha256=636d7432fa08c9384cb304a95175bac151a35ebd7ec90ab0dcc7fc313c6dd302
#   Stored in directory: /root/.cache/pip/wheels/75/78/21/68b124549c9bdc94f822c02fb9aa3578a669843f9767776bca
#   Building wheel for parse (setup.py): started
#   Building wheel for parse (setup.py): finished with status 'done'
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24581 sha256=576a02f38074771d97a7532045365bcc0063efbf8cbff25de0c4e4e796380215
#   Stored in directory: /root/.cache/pip/wheels/e5/33/1f/68392720485b3ecf125a69e700baaab7624616deedea2fa6e2
# Successfully built fa2 pyvis python-louvain bs4 parse
# Installing collected packages: pyee, parse, appdirs, xmltodict, websockets, pyquery, networkx, jsonpickle, install, python-louvain, pyppeteer, pandas, fake-useragent, fa2, bs4, wordcloud, requests_html, pyvis
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.5
#     Not uninstalling pandas at /shared-libs/python3.8/py/lib/python3.8/site-packages, outside environment /root/venv
#     Can't uninstall 'pandas'. No files were found to uninstall.
# Successfully installed appdirs-1.4.4 bs4-0.0.1 fa2-0.3.5 fake-useragent-1.1.1 install-1.3.5 jsonpickle-3.0.0 networkx-2.8.8 pandas-1.3.0 parse-1.19.0 pyee-8.2.2 pyppeteer-1.0.2 pyquery-1.4.3 python-louvain-0.16 pyvis-0.3.1 requests_html-0.10.0 websockets-10.4 wordcloud-1.8.2.2 xmltodict-0.13.0
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=baf77fd7-8a6f-46ea-a9f3-49866c0b5d34' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
